# %%
import pandas as pd
import numpy as np

train_data = pd.read_csv('same_season_test_data.csv')
train_data.head()
# Out:
#    id home_team_abbr away_team_abbr is_night_game home_pitcher away_pitcher  \
# 0   0            HXK            SAJ         False    henryto01    carraca01
# 1   1            VJV            DPS          True    swanser01    biagijo01
# 2   2            BPH            KJP          True    richaly01    dowdyky01
# 3   3            GLO            PJT         False    butleed01    gonzagi01
# 4   4            PDF            HAN         False    thompza01    widenta01
#
#    home_team_rest  away_team_rest  home_pitcher_rest  away_pitcher_rest  ...  \
# 0             1.0             1.0                5.0                5.0  ...
# 1             1.0             1.0                6.0                5.0  ...
# 2             2.0             2.0                7.0                6.0  ...
# 3             1.0             1.0                5.0                5.0  ...
# 4             1.0             1.0                NaN                6.0  ...
#
#    away_pitcher_H_batters_faced_skew  away_pitcher_BB_batters_faced_mean  \
# 0                           1.897061                           -0.021571
# 1                          -0.174718                            0.206991
# 2                           2.960091                           -0.027093
# 3                          -0.345691                           -0.517786
# 4                           0.948865                           -0.248708
#
#    away_pitcher_BB_batters_faced_std  away_pitcher_BB_batters_faced_skew  \
# 0                                NaN                            0.657736
# 1                          -0.365752                           -0.660023
# 2                           0.200172                                 NaN
# 3                          -0.160474                            0.970894
# 4                          -0.401949                           -0.229898
#
#    away_pitcher_leverage_index_avg_mean  away_pitcher_leverage_index_avg_std  \
# 0                             -0.105414                            -0.215965
# 1                             -0.166158                            -0.400556
# 2                             -0.088088                             1.423080
# 3                             -0.028288                            -0.272571
# 4                              0.047862                            -0.396524
#
#    away_pitcher_leverage_index_avg_skew  away_pitcher_wpa_def_mean  \
# 0                             -0.341056                   0.710790
# 1                              0.189584                  -0.129330
# 2                              1.902420                  -0.486104
# 3                             -0.366498                  -0.583598
# 4                             -0.862731                  -0.262628
#
#    away_pitcher_wpa_def_std  away_pitcher_wpa_def_skew
# 0                 -0.305795                  -1.103229
# 1                  0.467740                   0.873353
# 2                  0.380234                   0.944937
# 3                  0.654581                        NaN
# 4                  0.444447                  -0.113465
#
# [5 rows x 165 columns]

# %%
import pandas as pd

# Assuming your DataFrame is named df and the features are 'feature1' and 'feature2'
correlation = train_data['home_batting_batting_avg_10RA'].corr(train_data['home_batting_onbase_perc_10RA'])
print("Correlation:", correlation)
# Out:
# Correlation: 0.8652871792859949

# %%
# Assuming your DataFrame is named df and the features are 'feature1' and 'feature2'
correlation = train_data['home_batting_batting_avg_10RA'].corr(train_data['home_batting_batting_avg_mean'])
print("Correlation:", correlation)
# Out:
# Correlation: 0.367553939836941

# %%
train_data = train_data.applymap(lambda x: float(x) if isinstance(x, bool) else x)
# Out:
# /tmp/ipykernel_55647/2294140884.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   train_data = train_data.applymap(lambda x: float(x) if isinstance(x, bool) else x)

# %%
# import pandas as pd

# # Function to normalize date features
# def normalize_date_to_range(date_series):
#     # Convert to datetime
#     dates = pd.to_datetime(date_series)
#     # Find the min and max dates
#     min_date = dates.min()
#     max_date = dates.max()
#     # Calculate the total range of days
#     total_days = (max_date - min_date).days
#     # Normalize to range [0, 1]
#     normalized = (dates - min_date).dt.days / total_days
#     return normalized, min_date, max_date

# # Apply the function to your dataset
# train_data['date'], min_date, max_date = normalize_date_to_range(train_data['date'])

# # Print the min and max dates
# print(f"Min date: {min_date}, Max date: {max_date}")
# print(train_data.head())

# %%
# Map unique names to integers for both features without overlap
def map_non_overlapping_features(df, columns):
    # Collect unique names for each column
    mappings = {}
    current_index = 0
    for column in columns:
        unique_names = df[column].unique()
        column_mapping = {name: current_index + idx for idx, name in enumerate(unique_names)}
        mappings[column] = column_mapping
        current_index += len(unique_names)  # Ensure no overlap in indices
        # Apply the mapping
        df[column] = df[column].map(column_mapping)
    return df, mappings

# Apply to 'home_pitcher' and 'away_pitcher'
columns_to_map = ['home_pitcher', 'away_pitcher']
train_data, mappings = map_non_overlapping_features(train_data, columns_to_map)

# Display the result
print(train_data)
print("Mapping dictionaries:")
for column, mapping in mappings.items():
    print(f"{column}: {mapping}")
# Out:
#         id home_team_abbr away_team_abbr  is_night_game  home_pitcher  \
# 0        0            HXK            SAJ            0.0             0
# 1        1            VJV            DPS            1.0             1
# 2        2            BPH            KJP            1.0             2
# 3        3            GLO            PJT            0.0             3
# 4        4            PDF            HAN            0.0             4
# ...    ...            ...            ...            ...           ...
# 6180  6180            PJT            GLO            1.0           225
# 6181  6181            RLJ            KJP            0.0           152
# 6182  6182            VJV            DPS            1.0           337
# 6183  6183            KFH            FBW            0.0           168
# 6184  6184            UPV            KJP            1.0           235
#
#       away_pitcher  home_team_rest  away_team_rest  home_pitcher_rest  \
# 0              706             1.0             1.0                5.0
# 1              707             1.0             1.0                6.0
# 2              708             2.0             2.0                7.0
# 3              709             1.0             1.0                5.0
# 4              710             1.0             1.0                NaN
# ...            ...             ...             ...                ...
# 6180           851             1.0             1.0                6.0
# 6181          1011             1.0             1.0                6.0
# 6182           863             1.0             1.0                6.0
# 6183           943             1.0             1.0                5.0
# 6184           892             1.0             1.0                5.0
#
#       away_pitcher_rest  ...  away_pitcher_H_batters_faced_skew  \
# 0                   5.0  ...                           1.897061
# 1                   5.0  ...                          -0.174718
# 2                   6.0  ...                           2.960091
# 3                   5.0  ...                          -0.345691
# 4                   6.0  ...                           0.948865
# ...                 ...  ...                                ...
# 6180               97.0  ...                           3.392216
# 6181                6.0  ...                           1.209798
# 6182                5.0  ...                           0.174997
# 6183                5.0  ...                          -0.770237
# 6184                7.0  ...                                NaN
#
#       away_pitcher_BB_batters_faced_mean  away_pitcher_BB_batters_faced_std  \
# 0                              -0.021571                                NaN
# 1                               0.206991                          -0.365752
# 2                              -0.027093                           0.200172
# 3                              -0.517786                          -0.160474
# 4                              -0.248708                          -0.401949
# ...                                  ...                                ...
# 6180                            2.512546                           4.833286
# 6181                            0.162013                           1.156913
# 6182                           -0.045645                          -0.540794
# 6183                           -0.947281                          -0.962909
# 6184                           -0.192616                          -0.088209
#
#       away_pitcher_BB_batters_faced_skew  \
# 0                               0.657736
# 1                              -0.660023
# 2                                    NaN
# 3                               0.970894
# 4                              -0.229898
# ...                                  ...
# 6180                            0.604979
# 6181                            1.153948
# 6182                           -0.196066
# 6183                           -0.002763
# 6184                            2.260133
#
#       away_pitcher_leverage_index_avg_mean  \
# 0                                -0.105414
# 1                                -0.166158
# 2                                -0.088088
# 3                                -0.028288
# 4                                 0.047862
# ...                                    ...
# 6180                             -1.372334
# 6181                             -1.091520
# 6182                             -0.073852
# 6183                              0.198935
# 6184                              0.312213
#
#       away_pitcher_leverage_index_avg_std  \
# 0                               -0.215965
# 1                               -0.400556
# 2                                1.423080
# 3                               -0.272571
# 4                               -0.396524
# ...                                   ...
# 6180                             2.479468
# 6181                             0.352844
# 6182                            -0.194965
# 6183                            -0.014849
# 6184                             0.014994
#
#       away_pitcher_leverage_index_avg_skew  away_pitcher_wpa_def_mean  \
# 0                                -0.341056                   0.710790
# 1                                 0.189584                  -0.129330
# 2                                 1.902420                  -0.486104
# 3                                -0.366498                  -0.583598
# 4                                -0.862731                  -0.262628
# ...                                    ...                        ...
# 6180                                   NaN                  -0.515166
# 6181                             -1.393326                  -0.849379
# 6182                             -0.755898                   0.444184
# 6183                              0.392745                   0.690523
# 6184                             -0.210458                   0.898673
#
#       away_pitcher_wpa_def_std  away_pitcher_wpa_def_skew
# 0                    -0.305795                  -1.103229
# 1                     0.467740                   0.873353
# 2                     0.380234                   0.944937
# 3                     0.654581                        NaN
# 4                     0.444447                  -0.113465
# ...                        ...                        ...
# 6180                 -1.832176                  -2.189157
# 6181                 -1.228204                   0.145295
# 6182                  0.262688                   0.417515
# 6183                  0.815152                  -0.113742
# 6184                  0.601774                  -0.374478
#
# [6185 rows x 165 columns]
# Mapping dictionaries:
# home_pitcher: {'henryto01': 0, 'swanser01': 1, 'richaly01': 2, 'butleed01': 3, 'thompza01': 4, 'couloda01': 5, 'howarsa01': 6, 'givenmy01': 7, 'meisiry01': 8, 'nicolju01': 9, 'mckaybr01': 10, 'manoaal01': 11, 'widenta01': 12, 'iwakuhi01': 13, 'faedoal01': 14, 'schulja02': 15, 'carraca01': 16, 'palumjo01': 17, 'morgael01': 18, 'jonesja09': 19, 'castehu01': 20, nan: 21, 'newcose01': 22, 'gilbrlu01': 23, 'leonedo01': 24, 'fujinsh01': 25, 'fulmeca01': 26, 'strahma01': 27, 'matusbr01': 28, 'vinceni01': 29, 'mazurad01': 30, 'johnser04': 31, 'bumgama01': 32, 'bettial01': 33, 'hamilia01': 34, 'freelky01': 35, 'hanifbr01': 36, 'koehlto01': 37, 'penafe01': 38, 'johnsji04': 39, 'verrelo01': 40, 'stanery01': 41, 'bellch02': 42, 'wrighst01': 43, 'rodriya01': 44, 'kochaja01': 45, 'ashcrgr01': 46, 'hernafe02': 47, 'montafr02': 48, 'searsjp01': 49, 'battepe01': 50, 'briesbe01': 51, 'gonzami03': 52, 'triggan01': 53, 'nealza01': 54, 'fulmemi01': 55, 'wingetr01': 56, 'crawfku01': 57, 'scottch01': 58, 'medlekr01': 59, 'loupaa01': 60, 'abbotan01': 61, 'bolanro01': 62, 'leedy01': 63, 'sparkgl01': 64, 'rucindr01': 65, 'walstbl01': 66, 'rodrich01': 67, 'abbotco01': 68, 'kendrky01': 69, 'ortizlu03': 70, 'kiliaca01': 71, 'rodried05': 72, 'oviedjo01': 73, 'effrosc01': 74, 'francbo01': 75, 'gilbelo01': 76, 'warrewi01': 77, 'cottojh01': 78, 'leakemi01': 79, 'becktr01': 80, 'glasnty01': 81, 'birdsha01': 82, 'murfepe01': 83, 'megilty01': 84, 'diazjh01': 85, 'cuevawi01': 86, 'friedch01': 87, 'stammcr01': 88, 'litteza01': 89, 'curryxz01': 90, 'lauerer01': 91, 'danieda01': 92, 'sadleca02': 93, 'ucetaed01': 94, 'alexaty01': 95, 'bernabr01': 96, 'hoeinbr01': 97, 'adamsch01': 98, 'lawreca01': 99, 'nelsoji02': 100, 'hergeji01': 101, 'arihako01': 102, 'millesh01': 103, 'skenepa01': 104, 'nolaaa01': 105, 'grayjo02': 106, 'hughebr01': 107, 'carasma01': 108, 'hellije01': 109, 'coxau01': 110, 'garzaju01': 111, 'garcilu05': 112, 'thompke02': 113, 'iveyty01': 114, 'reaco01': 115, 'francjp01': 116, 'loaisjo01': 117, 'gonsoto01': 118, 'hatchto01': 119, 'kellemi03': 120, 'quintjo01': 121, 'bolsimi01': 122, 'suarejo01': 123, 'ennsdi01': 124, 'danaca01': 125, 'sheehem01': 126, 'parkebl01': 127, 'robleha01': 128, 'lewisco01': 129, 'feldmsc01': 130, 'wilkad01': 131, 'merriry01': 132, 'dicker.01': 133, 'norribu01': 134, 'mcfartj01': 135, 'hardybl01': 136, 'dunnju01': 137, 'adlemti01': 138, 'diazmi02': 139, 'hahnje01': 140, 'norrida01': 141, 'jarvibr01': 142, 'bergetr01': 143, 'tropeni01': 144, 'winanal01': 145, 'ynoahu01': 146, 'duplajo01': 147, 'woodtr01': 148, 'willitr01': 149, 'szaputh01': 150, 'skogler01': 151, 'schrejo01': 152, 'wilsoty01': 153, 'payamjo01': 154, 'reyesal02': 155, 'baumami01': 156, 'cravyty01': 157, 'oswalco01': 158, 'kelletr01': 159, 'urquijo01': 160, 'lopezre01': 161, 'singebr01': 162, 'wrighda04': 163, 'hendrli01': 164, 'zeuchtj01': 165, 'sanchaa01': 166, 'senzaan01': 167, 'waldike01': 168, 'ponceco01': 169, 'syndeno01': 170, 'maldoan01': 171, 'hessda01': 172, 'munozro01': 173, 'hugheph01': 174, 'gonzagi01': 175, 'davisau01': 176, 'mannima02': 177, 'strasst01': 178, 'harriky01': 179, 'sanchcr01': 180, 'pannoth01': 181, 'bellaan01': 182, 'thorple01': 183, 'nunezda01': 184, 'biagijo01': 185, 'corbipa01': 186, 'meyerma01': 187, 'kerrra01': 188, 'phillty01': 189, 'fostema01': 190, 'erlinro01': 191, 'smithaj01': 192, 'hernajo02': 193, 'adamsau02': 194, 'lorenmi01': 195, 'scholje01': 196, 'brighje01': 197, 'hauscmi01': 198, 'morejad01': 199, 'jacqujo01': 200, 'luetglu01': 201, 'wrighmi01': 202, 'millsal02': 203, 'neideni01': 204, 'detmere01': 205, 'hentgsa01': 206, 'rodrije01': 207, 'colege01': 208, 'honeybr01': 209, 'geedi01': 210, 'llovema01': 211, 'bassich01': 212, 'dermoma01': 213, 'martefr01': 214, 'bundydy01': 215, 'bendean01': 216, 'waltean01': 217, 'gsellro01': 218, 'peterda01': 219, 'schwesp01': 220, 'lackejo01': 221, 'sandopa02': 222, 'silsech01': 223, 'felizmi01': 224, 'dunnida01': 225, 'yanghy01': 226, 'buehlwa01': 227, 'wrighky01': 228, 'suarean01 ...
# away_pitcher: {'carraca01': 706, 'biagijo01': 707, 'dowdyky01': 708, 'gonzagi01': 709, 'widenta01': 710, 'montera01': 711, 'norrida01': 712, 'pannoth01': 713, 'tropeni01': 714, 'thorntr01': 715, 'oviedjo01': 716, 'bolsimi01': 717, 'bibenau01': 718, 'taillja01': 719, 'hanifbr01': 720, 'rouppla01': 721, 'bautige01': 722, 'gassero01': 723, 'duplajo01': 724, 'grayjo02': 725, 'plesaza01': 726, 'parkebl01': 727, 'campbpa02': 728, nan: 729, 'parkemi01': 730, 'niesejo01': 731, 'knebeco01': 732, 'duffyda01': 733, 'medlekr01': 734, 'civalaa01': 735, 'wainwad01': 736, 'cravyty01': 737, 'selbyco01': 738, 'nunezda01': 739, 'jayemy01': 740, 'kochaja01': 741, 'graveke01': 742, 'hoeinbr01': 743, 'kendrky01': 744, 'iwakuhi01': 745, 'sadleca02': 746, 'kochma01': 747, 'smithaj01': 748, 'wilkad01': 749, 'ucetaed01': 750, 'litteza01': 751, 'delarru01': 752, 'rogertr01': 753, 'antonte01': 754, 'wrighmi01': 755, 'abbotco01': 756, 'henlebl01': 757, 'johnsji04': 758, 'soriajo01': 759, 'howarsp01': 760, 'vargace01': 761, 'adamsau02': 762, 'asheral01': 763, 'tsengje01': 764, 'neideni01': 765, 'hernaca04': 766, 'llovema01': 767, 'garream01': 768, 'elderbr01': 769, 'anderta01': 770, 'jeffeda01': 771, 'rodrije01': 772, 'swanser01': 773, 'willitr01': 774, 'kintzbr01': 775, 'bassich01': 776, 'oswalco01': 777, 'suarean01': 778, 'sheehem01': 779, 'scottch01': 780, 'rucindr01': 781, 'leonedo01': 782, 'butleed01': 783, 'conlead01': 784, 'adamsch01': 785, 'dunnju01': 786, 'chiriyo01': 787, 'nealza01': 788, 'waldike01': 789, 'matthze01': 790, 'mcguide02': 791, 'poteeco01': 792, 'sprinje01': 793, 'hatchto01': 794, 'willibr02': 795, 'paddach01': 796, 'slegeaa01': 797, 'leedy01': 798, 'gracema02': 799, 'phillty01': 800, 'couloda01': 801, 'briesbe01': 802, 'rutleja01': 803, 'pepiory01': 804, 'simslu01': 805, 'reyesal02': 806, 'liriafr01': 807, 'nicolju01': 808, 'feltnry01': 809, 'jacqujo01': 810, 'effrosc01': 811, 'suarejo01': 812, 'thompke02': 813, 'jacksed01': 814, 'bendean01': 815, 'cruzfe01': 816, 'fujinsh01': 817, 'bradiky01': 818, 'gilbelo01': 819, 'allenlo02': 820, 'danieda01': 821, 'colege01': 822, 'kittran01': 823, 'wrighky01': 824, 'delosen01': 825, 'conlopj01': 826, 'bettial01': 827, 'murfepe01': 828, 'battepe01': 829, 'nixja02': 830, 'johnser04': 831, 'mckaybr01': 832, 'gearrco01': 833, 'borucry01': 834, 'gsellro01': 835, 'estesjo01': 836, 'rodriya01': 837, 'simonal01': 838, 'bradlta01': 839, 'henryto01': 840, 'fulmemi01': 841, 'leakemi01': 842, 'hessda01': 843, 'burneco01': 844, 'yarbrry01': 845, 'diazmi02': 846, 'floreke01': 847, 'allarko01': 848, 'millebo06': 849, 'farmebu01': 850, 'matusbr01': 851, 'maldoan01': 852, 'hergeji01': 853, 'stanery01': 854, 'felizmi01': 855, 'ramirne01': 856, 'kerrra01': 857, 'kiliaca01': 858, 'lewisco01': 859, 'mazurad01': 860, 'sotogr01': 861, 'walstbl01': 862, 'faedoal01': 863, 'castehu01': 864, 'morgaad01': 865, 'scholje01': 866, 'sorokmi01': 867, 'chenwe02': 868, 'iveyty01': 869, 'buehlwa01': 870, 'sandopa02': 871, 'lakintr01': 872, 'corbipa01': 873, 'holmegr01': 874, 'feldmsc01': 875, 'latzja01': 876, 'anderco01': 877, 'merryju01': 878, 'erlinro01': 879, 'littllu01': 880, 'vothau01': 881, 'bellch02': 882, 'jimenub01': 883, 'merriry01': 884, 'birdja01': 885, 'shiplbr01': 886, 'warrewi01': 887, 'carasma01': 888, 'senzaan01': 889, 'sborzjo01': 890, 'reaco01': 891, 'wrighda04': 892, 'overtco01': 893, 'eflinza01': 894, 'hellije01': 895, 'andrima01': 896, 'curryxz01': 897, 'hentgsa01': 898, 'ashcrgr01': 899, 'kellemi03': 900, 'hernajo02': 901, 'morgael01': 902, 'danaca01': 903, 'turnbsp01': 904, 'middlke01': 905, 'claudal01': 906, 'mejiahu01': 907, 'jimenda01': 908, 'wellsal01': 909, 'peavyja01': 910, 'minormi01': 911, 'koenija01': 912, 'bakerbr01': 913, 'ponceco01': 914, 'armstsh01': 915, 'ceasedy01': 916, 'latosma01': 917, 'arihako01': 918, 'desclan01': 919, 'hutchdr01': 920, 'nolasri01': 921, 'crochga01': 922, 'hernafe02': 923, 'cobbal01': 924, 'adlemti01': 925, 'strasst01': 926, 'skogler01': 927, 'silsech01': 928, 'marsh ...

# %%
# Map unique names to integers for both features without overlap
def map_non_overlapping_features(df, columns):
    # Collect unique names for each column
    mappings = {}
    current_index = 0
    for column in columns:
        unique_names = df[column].unique()
        column_mapping = {name: current_index + idx for idx, name in enumerate(unique_names)}
        mappings[column] = column_mapping
        current_index += len(unique_names)  # Ensure no overlap in indices
        # Apply the mapping
        df[column] = df[column].map(column_mapping)
    return df, mappings

# Apply to 'home_pitcher' and 'away_pitcher'
columns_to_map = ['home_team_abbr', 'away_team_abbr']
train_data, mappings = map_non_overlapping_features(train_data, columns_to_map)

# Display the result
print(train_data)
print("Mapping dictionaries:")
for column, mapping in mappings.items():
    print(f"{column}: {mapping}")
# Out:
#         id  home_team_abbr  away_team_abbr  is_night_game  home_pitcher  \
# 0        0               0              30            0.0             0
# 1        1               1              31            1.0             1
# 2        2               2              32            1.0             2
# 3        3               3              33            0.0             3
# 4        4               4              34            0.0             4
# ...    ...             ...             ...            ...           ...
# 6180  6180              22              50            1.0           225
# 6181  6181              18              32            0.0           152
# 6182  6182               1              31            1.0           337
# 6183  6183              10              54            0.0           168
# 6184  6184               8              32            1.0           235
#
#       away_pitcher  home_team_rest  away_team_rest  home_pitcher_rest  \
# 0              706             1.0             1.0                5.0
# 1              707             1.0             1.0                6.0
# 2              708             2.0             2.0                7.0
# 3              709             1.0             1.0                5.0
# 4              710             1.0             1.0                NaN
# ...            ...             ...             ...                ...
# 6180           851             1.0             1.0                6.0
# 6181          1011             1.0             1.0                6.0
# 6182           863             1.0             1.0                6.0
# 6183           943             1.0             1.0                5.0
# 6184           892             1.0             1.0                5.0
#
#       away_pitcher_rest  ...  away_pitcher_H_batters_faced_skew  \
# 0                   5.0  ...                           1.897061
# 1                   5.0  ...                          -0.174718
# 2                   6.0  ...                           2.960091
# 3                   5.0  ...                          -0.345691
# 4                   6.0  ...                           0.948865
# ...                 ...  ...                                ...
# 6180               97.0  ...                           3.392216
# 6181                6.0  ...                           1.209798
# 6182                5.0  ...                           0.174997
# 6183                5.0  ...                          -0.770237
# 6184                7.0  ...                                NaN
#
#       away_pitcher_BB_batters_faced_mean  away_pitcher_BB_batters_faced_std  \
# 0                              -0.021571                                NaN
# 1                               0.206991                          -0.365752
# 2                              -0.027093                           0.200172
# 3                              -0.517786                          -0.160474
# 4                              -0.248708                          -0.401949
# ...                                  ...                                ...
# 6180                            2.512546                           4.833286
# 6181                            0.162013                           1.156913
# 6182                           -0.045645                          -0.540794
# 6183                           -0.947281                          -0.962909
# 6184                           -0.192616                          -0.088209
#
#       away_pitcher_BB_batters_faced_skew  \
# 0                               0.657736
# 1                              -0.660023
# 2                                    NaN
# 3                               0.970894
# 4                              -0.229898
# ...                                  ...
# 6180                            0.604979
# 6181                            1.153948
# 6182                           -0.196066
# 6183                           -0.002763
# 6184                            2.260133
#
#       away_pitcher_leverage_index_avg_mean  \
# 0                                -0.105414
# 1                                -0.166158
# 2                                -0.088088
# 3                                -0.028288
# 4                                 0.047862
# ...                                    ...
# 6180                             -1.372334
# 6181                             -1.091520
# 6182                             -0.073852
# 6183                              0.198935
# 6184                              0.312213
#
#       away_pitcher_leverage_index_avg_std  \
# 0                               -0.215965
# 1                               -0.400556
# 2                                1.423080
# 3                               -0.272571
# 4                               -0.396524
# ...                                   ...
# 6180                             2.479468
# 6181                             0.352844
# 6182                            -0.194965
# 6183                            -0.014849
# 6184                             0.014994
#
#       away_pitcher_leverage_index_avg_skew  away_pitcher_wpa_def_mean  \
# 0                                -0.341056                   0.710790
# 1                                 0.189584                  -0.129330
# 2                                 1.902420                  -0.486104
# 3                                -0.366498                  -0.583598
# 4                                -0.862731                  -0.262628
# ...                                    ...                        ...
# 6180                                   NaN                  -0.515166
# 6181                             -1.393326                  -0.849379
# 6182                             -0.755898                   0.444184
# 6183                              0.392745                   0.690523
# 6184                             -0.210458                   0.898673
#
#       away_pitcher_wpa_def_std  away_pitcher_wpa_def_skew
# 0                    -0.305795                  -1.103229
# 1                     0.467740                   0.873353
# 2                     0.380234                   0.944937
# 3                     0.654581                        NaN
# 4                     0.444447                  -0.113465
# ...                        ...                        ...
# 6180                 -1.832176                  -2.189157
# 6181                 -1.228204                   0.145295
# 6182                  0.262688                   0.417515
# 6183                  0.815152                  -0.113742
# 6184                  0.601774                  -0.374478
#
# [6185 rows x 165 columns]
# Mapping dictionaries:
# home_team_abbr: {'HXK': 0, 'VJV': 1, 'BPH': 2, 'GLO': 3, 'PDF': 4, 'DPS': 5, 'SAJ': 6, 'GKO': 7, 'UPV': 8, 'QDH': 9, 'KFH': 10, 'HAN': 11, 'GUT': 12, 'MOO': 13, 'MZG': 14, 'JBM': 15, 'JEM': 16, 'STC': 17, 'RLJ': 18, 'ZQF': 19, 'RAV': 20, 'RKN': 21, 'PJT': 22, 'FBW': 23, 'QPO': 24, 'YHA': 25, 'XFB': 26, 'VQC': 27, 'KJP': 28, 'ECN': 29}
# away_team_abbr: {'SAJ': 30, 'DPS': 31, 'KJP': 32, 'PJT': 33, 'HAN': 34, 'RKN': 35, 'KFH': 36, 'JEM': 37, 'VJV': 38, 'MOO': 39, 'JBM': 40, 'STC': 41, 'GUT': 42, 'YHA': 43, 'QDH': 44, 'UPV': 45, 'XFB': 46, 'GKO': 47, 'MZG': 48, 'QPO': 49, 'GLO': 50, 'HXK': 51, 'BPH': 52, 'ZQF': 53, 'FBW': 54, 'VQC': 55, 'PDF': 56, 'RAV': 57, 'RLJ': 58, 'ECN': 59}

# %%
# Drop non-integer and non-float columns
train_data = train_data.select_dtypes(include=['int64', 'float64'])

# Display the resulting DataFrame
print(train_data)
# Out:
#         id  home_team_abbr  away_team_abbr  is_night_game  home_pitcher  \
# 0        0               0              30            0.0             0
# 1        1               1              31            1.0             1
# 2        2               2              32            1.0             2
# 3        3               3              33            0.0             3
# 4        4               4              34            0.0             4
# ...    ...             ...             ...            ...           ...
# 6180  6180              22              50            1.0           225
# 6181  6181              18              32            0.0           152
# 6182  6182               1              31            1.0           337
# 6183  6183              10              54            0.0           168
# 6184  6184               8              32            1.0           235
#
#       away_pitcher  home_team_rest  away_team_rest  home_pitcher_rest  \
# 0              706             1.0             1.0                5.0
# 1              707             1.0             1.0                6.0
# 2              708             2.0             2.0                7.0
# 3              709             1.0             1.0                5.0
# 4              710             1.0             1.0                NaN
# ...            ...             ...             ...                ...
# 6180           851             1.0             1.0                6.0
# 6181          1011             1.0             1.0                6.0
# 6182           863             1.0             1.0                6.0
# 6183           943             1.0             1.0                5.0
# 6184           892             1.0             1.0                5.0
#
#       away_pitcher_rest  ...  away_pitcher_H_batters_faced_skew  \
# 0                   5.0  ...                           1.897061
# 1                   5.0  ...                          -0.174718
# 2                   6.0  ...                           2.960091
# 3                   5.0  ...                          -0.345691
# 4                   6.0  ...                           0.948865
# ...                 ...  ...                                ...
# 6180               97.0  ...                           3.392216
# 6181                6.0  ...                           1.209798
# 6182                5.0  ...                           0.174997
# 6183                5.0  ...                          -0.770237
# 6184                7.0  ...                                NaN
#
#       away_pitcher_BB_batters_faced_mean  away_pitcher_BB_batters_faced_std  \
# 0                              -0.021571                                NaN
# 1                               0.206991                          -0.365752
# 2                              -0.027093                           0.200172
# 3                              -0.517786                          -0.160474
# 4                              -0.248708                          -0.401949
# ...                                  ...                                ...
# 6180                            2.512546                           4.833286
# 6181                            0.162013                           1.156913
# 6182                           -0.045645                          -0.540794
# 6183                           -0.947281                          -0.962909
# 6184                           -0.192616                          -0.088209
#
#       away_pitcher_BB_batters_faced_skew  \
# 0                               0.657736
# 1                              -0.660023
# 2                                    NaN
# 3                               0.970894
# 4                              -0.229898
# ...                                  ...
# 6180                            0.604979
# 6181                            1.153948
# 6182                           -0.196066
# 6183                           -0.002763
# 6184                            2.260133
#
#       away_pitcher_leverage_index_avg_mean  \
# 0                                -0.105414
# 1                                -0.166158
# 2                                -0.088088
# 3                                -0.028288
# 4                                 0.047862
# ...                                    ...
# 6180                             -1.372334
# 6181                             -1.091520
# 6182                             -0.073852
# 6183                              0.198935
# 6184                              0.312213
#
#       away_pitcher_leverage_index_avg_std  \
# 0                               -0.215965
# 1                               -0.400556
# 2                                1.423080
# 3                               -0.272571
# 4                               -0.396524
# ...                                   ...
# 6180                             2.479468
# 6181                             0.352844
# 6182                            -0.194965
# 6183                            -0.014849
# 6184                             0.014994
#
#       away_pitcher_leverage_index_avg_skew  away_pitcher_wpa_def_mean  \
# 0                                -0.341056                   0.710790
# 1                                 0.189584                  -0.129330
# 2                                 1.902420                  -0.486104
# 3                                -0.366498                  -0.583598
# 4                                -0.862731                  -0.262628
# ...                                    ...                        ...
# 6180                                   NaN                  -0.515166
# 6181                             -1.393326                  -0.849379
# 6182                             -0.755898                   0.444184
# 6183                              0.392745                   0.690523
# 6184                             -0.210458                   0.898673
#
#       away_pitcher_wpa_def_std  away_pitcher_wpa_def_skew
# 0                    -0.305795                  -1.103229
# 1                     0.467740                   0.873353
# 2                     0.380234                   0.944937
# 3                     0.654581                        NaN
# 4                     0.444447                  -0.113465
# ...                        ...                        ...
# 6180                 -1.832176                  -2.189157
# 6181                 -1.228204                   0.145295
# 6182                  0.262688                   0.417515
# 6183                  0.815152                  -0.113742
# 6184                  0.601774                  -0.374478
#
# [6185 rows x 163 columns]

# %%
from sklearn.linear_model import LinearRegression
print("LinearRegression imported successfully!")
# Out:
# LinearRegression imported successfully!

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from tqdm import tqdm

def fill_missing_using_correlation(df):
    # Compute the correlation matrix
    corr_matrix = df.corr()

    # Iterate over each column
    for col in tqdm(df.columns):
        if df[col].isna().any():  # Only process columns with missing values
            # Find the column with the highest absolute correlation to the current column
            corr_col = corr_matrix[col].drop(col).idxmax()

            # Drop rows where either column is NaN to fit the linear model
            valid_data = df[[col, corr_col]].dropna()
            if valid_data.empty or valid_data[corr_col].isna().all():
                # Skip if no valid data exists for linear regression
                continue

            # Fit a linear regression model
            X = valid_data[[corr_col]].values.reshape(-1, 1)  # Independent variable
            y = valid_data[col].values                        # Dependent variable
            model = LinearRegression()
            model.fit(X, y)

            # Handle missing values in the correlated column
            missing_corr_col_indices = df[df[corr_col].isna()].index
            if not missing_corr_col_indices.empty:
                # Fill missing correlated column values with its mean
                df.loc[missing_corr_col_indices, corr_col] = df[corr_col].mean()

            # Predict missing values using the linear model
            missing_indices = df[df[col].isna()].index
            df.loc[missing_indices, col] = model.predict(df.loc[missing_indices, [corr_col]].values.reshape(-1, 1))

            # Fill any remaining NaN with the column mean as fallback
            df[col] = df[col].fillna(df[col].mean())

    # Handle rows that are entirely NaN by filling with column means
    df = df.apply(lambda row: row.fillna(df.mean()), axis=1)

    return df

# Example usage
# Assume train_data is your DataFrame with missing values
train_data = fill_missing_using_correlation(train_data)

# Display the result
print(train_data)
# Out:
# 100%|██████████| 163/163 [00:00<00:00, 537.14it/s]
#           id  home_team_abbr  away_team_abbr  is_night_game  home_pitcher  \
# 0        0.0             0.0            30.0            0.0           0.0
# 1        1.0             1.0            31.0            1.0           1.0
# 2        2.0             2.0            32.0            1.0           2.0
# 3        3.0             3.0            33.0            0.0           3.0
# 4        4.0             4.0            34.0            0.0           4.0
# ...      ...             ...             ...            ...           ...
# 6180  6180.0            22.0            50.0            1.0         225.0
# 6181  6181.0            18.0            32.0            0.0         152.0
# 6182  6182.0             1.0            31.0            1.0         337.0
# 6183  6183.0            10.0            54.0            0.0         168.0
# 6184  6184.0             8.0            32.0            1.0         235.0
#
#       away_pitcher  home_team_rest  away_team_rest  home_pitcher_rest  \
# 0            706.0             1.0             1.0           5.000000
# 1            707.0             1.0             1.0           6.000000
# 2            708.0             2.0             2.0           7.000000
# 3            709.0             1.0             1.0           5.000000
# 4            710.0             1.0             1.0          13.157262
# ...            ...             ...             ...                ...
# 6180         851.0             1.0             1.0           6.000000
# 6181        1011.0             1.0             1.0           6.000000
# 6182         863.0             1.0             1.0           6.000000
# 6183         943.0             1.0             1.0           5.000000
# 6184         892.0             1.0             1.0           5.000000
#
#       away_pitcher_rest  ...  away_pitcher_H_batters_faced_skew  \
# 0                   5.0  ...                           1.897061
# 1                   5.0  ...                          -0.174718
# 2                   6.0  ...                           2.960091
# 3                   5.0  ...                          -0.345691
# 4                   6.0  ...                           0.948865
# ...                 ...  ...                                ...
# 6180               97.0  ...                           3.392216
# 6181                6.0  ...                           1.209798
# 6182                5.0  ...                           0.174997
# 6183                5.0  ...                          -0.770237
# 6184                7.0  ...                           1.122035
#
#       away_pitcher_BB_batters_faced_mean  away_pitcher_BB_batters_faced_std  \
# 0                              -0.021571                          -0.102833
# 1                               0.206991                          -0.365752
# 2                              -0.027093                           0.200172
# 3                              -0.517786                          -0.160474
# 4                              -0.248708                          -0.401949
# ...                                  ...                                ...
# 6180                            2.512546                           4.833286
# 6181                            0.162013                           1.156913
# 6182                           -0.045645                          -0.540794
# 6183                           -0.947281                          -0.962909
# 6184                           -0.192616                          -0.088209
#
#       away_pitcher_BB_batters_faced_skew  \
# 0                               0.657736
# 1                              -0.660023
# 2                               0.216810
# 3                               0.970894
# 4                              -0.229898
# ...                                  ...
# 6180                            0.604979
# 6181                            1.153948
# 6182                           -0.196066
# 6183                           -0.002763
# 6184                            2.260133
#
#       away_pitcher_leverage_index_avg_mean  \
# 0                                -0.105414
# 1                                -0.166158
# 2                                -0.088088
# 3                                -0.028288
# 4                                 0.047862
# ...                                    ...
# 6180                             -1.372334
# 6181                             -1.091520
# 6182                             -0.073852
# 6183                              0.198935
# 6184                              0.312213
#
#       away_pitcher_leverage_index_avg_std  \
# 0                               -0.215965
# 1                               -0.400556
# 2                                1.423080
# 3                               -0.272571
# 4                               -0.396524
# ...                                   ...
# 6180                             2.479468
# 6181                             0.352844
# 6182                            -0.194965
# 6183                            -0.014849
# 6184                             0.014994
#
#       away_pitcher_leverage_index_avg_skew  away_pitcher_wpa_def_mean  \
# 0                                -0.341056                   0.710790
# 1                                 0.189584                  -0.129330
# 2                                 1.902420                  -0.486104
# 3                                -0.366498                  -0.583598
# 4                                -0.862731                  -0.262628
# ...                                    ...                        ...
# 6180                              1.502552                  -0.515166
# 6181                             -1.393326                  -0.849379
# 6182                             -0.755898                   0.444184
# 6183                              0.392745                   0.690523
# 6184                             -0.210458                   0.898673
#
#       away_pitcher_wpa_def_std  away_pitcher_wpa_def_skew
# 0                    -0.305795                  -1.103229
# 1                     0.467740                   0.873353
# 2                     0.380234                   0.944937
# 3                     0.654581                   0.215522
# 4                     0.444447                  -0.113465
# ...                        ...                        ...
# 6180                 -1.832176                  -2.189157
# 6181                 -1.228204                   0.145295
# 6182                  0.262688                   0.417515
# 6183                  0.815152                  -0.113742
# 6184                  0.601774                  -0.374478
#
# [6185 rows x 163 columns]

# %%
# Check if there are any NaN values in the DataFrame
has_nan = train_data.isna().any().any()

# Output the result
if has_nan:
    print("There are NaN values in train_data.")
else:
    print("No NaN values in train_data.")
# Out:
# No NaN values in train_data.

# %%
# Save the DataFrame to a CSV file
train_data.to_csv('stage1_test_data_imputation.csv', index=False)

print("train_data has been saved to train_data_imputation.csv")
# Out:
# train_data has been saved to train_data_imputation.csv
