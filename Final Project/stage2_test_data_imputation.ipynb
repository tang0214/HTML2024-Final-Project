# %%
import pandas as pd
import numpy as np

train_data = pd.read_csv('./stage2_data/2024_test_data.csv')
train_data.head()
# Out:
#    id home_team_abbr away_team_abbr is_night_game home_pitcher away_pitcher  \
# 0   0            DPS            SAJ         False    blairaa01     dunnju01
# 1   1            JEM            GKO          True    mejiaje02    hatchto01
# 2   2            MZG            HAN          True    battepe01     iveyty01
# 3   3            GKO            JEM          True    hellije01    sadleca02
# 4   4            UPV            SAJ         False    carraca01    bolsimi01
#
#    home_team_rest  away_team_rest  home_pitcher_rest  away_pitcher_rest  ...  \
# 0             1.0             1.0                7.0                6.0  ...
# 1             1.0             2.0               13.0                6.0  ...
# 2             1.0             1.0                6.0                NaN  ...
# 3             1.0             1.0                6.0                6.0  ...
# 4             NaN             NaN                6.0                NaN  ...
#
#    away_pitcher_H_batters_faced_skew  away_pitcher_BB_batters_faced_mean  \
# 0                           1.137587                           -0.202847
# 1                           0.977567                           -0.714865
# 2                           0.787161                           -0.220152
# 3                           1.845729                            1.178937
# 4                                NaN                            1.609123
#
#    away_pitcher_BB_batters_faced_std  away_pitcher_BB_batters_faced_skew  \
# 0                          -0.169020                           -0.365553
# 1                          -0.838365                           -0.428443
# 2                          -0.530733                           -1.110442
# 3                           1.585955                            0.066516
# 4                                NaN                                 NaN
#
#    away_pitcher_leverage_index_avg_mean  away_pitcher_leverage_index_avg_std  \
# 0                             -0.227047                            -0.295909
# 1                             -0.124948                            -0.281637
# 2                             -0.549621                            -0.021826
# 3                              0.521931                            -0.393085
# 4                              1.025560                                  NaN
#
#    away_pitcher_leverage_index_avg_skew  away_pitcher_wpa_def_mean  \
# 0                              0.686374                  -0.203924
# 1                              1.065657                  -0.282993
# 2                              0.494930                  -1.128590
# 3                              0.712029                   0.546615
# 4                                   NaN                  -0.600823
#
#    away_pitcher_wpa_def_std  away_pitcher_wpa_def_skew
# 0                  0.245775                  -0.510284
# 1                       NaN                   0.191600
# 2                 -0.184698                   0.851088
# 3                 -0.240162                  -0.625477
# 4                       NaN                        NaN
#
# [5 rows x 165 columns]

# %%
import pandas as pd

# Assuming your DataFrame is named df and the features are 'feature1' and 'feature2'
correlation = train_data['home_batting_batting_avg_10RA'].corr(train_data['home_batting_onbase_perc_10RA'])
print("Correlation:", correlation)
# Out:
# Correlation: 0.8758630060850919

# %%
# Assuming your DataFrame is named df and the features are 'feature1' and 'feature2'
correlation = train_data['home_batting_batting_avg_10RA'].corr(train_data['home_batting_batting_avg_mean'])
print("Correlation:", correlation)
# Out:
# Correlation: 0.6279291955811135

# %%
train_data = train_data.applymap(lambda x: float(x) if isinstance(x, bool) else x)
# Out:
# /tmp/ipykernel_56680/2294140884.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   train_data = train_data.applymap(lambda x: float(x) if isinstance(x, bool) else x)

# %%
# import pandas as pd

# # Function to normalize date features
# def normalize_date_to_range(date_series):
#     # Convert to datetime
#     dates = pd.to_datetime(date_series)
#     # Find the min and max dates
#     min_date = dates.min()
#     max_date = dates.max()
#     # Calculate the total range of days
#     total_days = (max_date - min_date).days
#     # Normalize to range [0, 1]
#     normalized = (dates - min_date).dt.days / total_days
#     return normalized, min_date, max_date

# # Apply the function to your dataset
# train_data['date'], min_date, max_date = normalize_date_to_range(train_data['date'])

# # Print the min and max dates
# print(f"Min date: {min_date}, Max date: {max_date}")
# print(train_data.head())

# %%
# Map unique names to integers for both features without overlap
def map_non_overlapping_features(df, columns):
    # Collect unique names for each column
    mappings = {}
    current_index = 0
    for column in columns:
        unique_names = df[column].unique()
        column_mapping = {name: current_index + idx for idx, name in enumerate(unique_names)}
        mappings[column] = column_mapping
        current_index += len(unique_names)  # Ensure no overlap in indices
        # Apply the mapping
        df[column] = df[column].map(column_mapping)
    return df, mappings

# Apply to 'home_pitcher' and 'away_pitcher'
columns_to_map = ['home_pitcher', 'away_pitcher']
train_data, mappings = map_non_overlapping_features(train_data, columns_to_map)

# Display the result
print(train_data)
print("Mapping dictionaries:")
for column, mapping in mappings.items():
    print(f"{column}: {mapping}")
# Out:
#         id home_team_abbr away_team_abbr  is_night_game  home_pitcher  \
# 0        0            DPS            SAJ            0.0             0
# 1        1            JEM            GKO            1.0             1
# 2        2            MZG            HAN            1.0             2
# 3        3            GKO            JEM            1.0             3
# 4        4            UPV            SAJ            0.0             4
# ...    ...            ...            ...            ...           ...
# 2423  2423            PDF            KFH            0.0           327
# 2424  2424            SAJ            VJV            1.0            18
# 2425  2425            RKN            DPS            1.0            47
# 2426  2426            FBW            VQC            1.0           104
# 2427  2427            PJT            VQC            0.0            17
#
#       away_pitcher  home_team_rest  away_team_rest  home_pitcher_rest  \
# 0              328             1.0             1.0                7.0
# 1              329             1.0             2.0               13.0
# 2              330             1.0             1.0                6.0
# 3              331             1.0             1.0                6.0
# 4              332             NaN             NaN                6.0
# ...            ...             ...             ...                ...
# 2423           504             1.0             1.0                7.0
# 2424           591             1.0             1.0                6.0
# 2425           563             1.0             1.0                7.0
# 2426           506             1.0             1.0                6.0
# 2427           506             1.0             1.0                5.0
#
#       away_pitcher_rest  ...  away_pitcher_H_batters_faced_skew  \
# 0                   6.0  ...                           1.137587
# 1                   6.0  ...                           0.977567
# 2                   NaN  ...                           0.787161
# 3                   6.0  ...                           1.845729
# 4                   NaN  ...                                NaN
# ...                 ...  ...                                ...
# 2423                5.0  ...                          -0.355111
# 2424                5.0  ...                          -0.328963
# 2425               46.0  ...                          -0.910894
# 2426                6.0  ...                          -0.508469
# 2427                6.0  ...                          -0.546845
#
#       away_pitcher_BB_batters_faced_mean  away_pitcher_BB_batters_faced_std  \
# 0                              -0.202847                          -0.169020
# 1                              -0.714865                          -0.838365
# 2                              -0.220152                          -0.530733
# 3                               1.178937                           1.585955
# 4                               1.609123                                NaN
# ...                                  ...                                ...
# 2423                           -2.021044                          -1.344937
# 2424                           -0.131224                           0.386066
# 2425                           -0.771246                          -0.523058
# 2426                            0.009715                           1.124424
# 2427                            0.069352                           1.576071
#
#       away_pitcher_BB_batters_faced_skew  \
# 0                              -0.365553
# 1                              -0.428443
# 2                              -1.110442
# 3                               0.066516
# 4                                    NaN
# ...                                  ...
# 2423                            1.476650
# 2424                           -0.677908
# 2425                            0.146930
# 2426                            0.742245
# 2427                            0.564578
#
#       away_pitcher_leverage_index_avg_mean  \
# 0                                -0.227047
# 1                                -0.124948
# 2                                -0.549621
# 3                                 0.521931
# 4                                 1.025560
# ...                                    ...
# 2423                             -0.512116
# 2424                             -0.919306
# 2425                              0.157603
# 2426                              0.806562
# 2427                              1.156825
#
#       away_pitcher_leverage_index_avg_std  \
# 0                               -0.295909
# 1                               -0.281637
# 2                               -0.021826
# 3                               -0.393085
# 4                                     NaN
# ...                                   ...
# 2423                            -0.686262
# 2424                            -0.354241
# 2425                            -0.764696
# 2426                             2.978556
# 2427                             3.574703
#
#       away_pitcher_leverage_index_avg_skew  away_pitcher_wpa_def_mean  \
# 0                                 0.686374                  -0.203924
# 1                                 1.065657                  -0.282993
# 2                                 0.494930                  -1.128590
# 3                                 0.712029                   0.546615
# 4                                      NaN                  -0.600823
# ...                                    ...                        ...
# 2423                                   NaN                   0.191498
# 2424                              0.252490                  -1.200417
# 2425                             -0.709722                  -0.438879
# 2426                              1.911847                   0.486277
# 2427                              1.627607                   0.565352
#
#       away_pitcher_wpa_def_std  away_pitcher_wpa_def_skew
# 0                     0.245775                  -0.510284
# 1                          NaN                   0.191600
# 2                    -0.184698                   0.851088
# 3                    -0.240162                  -0.625477
# 4                          NaN                        NaN
# ...                        ...                        ...
# 2423                       NaN                   0.187264
# 2424                  1.247802                   0.616256
# 2425                 -0.397830                   1.075658
# 2426                 -0.044440                   1.138141
# 2427                       NaN                   1.495294
#
# [2428 rows x 165 columns]
# Mapping dictionaries:
# home_pitcher: {'blairaa01': 0, 'mejiaje02': 1, 'battepe01': 2, 'hellije01': 3, 'carraca01': 4, 'anderdr02': 5, nan: 6, 'sorokmi01': 7, 'lopezpa01': 8, 'butleed01': 9, 'stammcr01': 10, 'vargace01': 11, 'feldmsc01': 12, 'klubeco01': 13, 'ceccosl01': 14, 'boshebu01': 15, 'poteeco01': 16, 'fulmemi01': 17, 'jeffrje01': 18, 'wainwad01': 19, 'mcallza01': 20, 'henriro01': 21, 'wolfja01': 22, 'housead01': 23, 'grayjo02': 24, 'kranima01': 25, 'bolsimi01': 26, 'buehlwa01': 27, 'brookaa01': 28, 'raganco01': 29, 'smithaj01': 30, 'flynnbr01': 31, 'rucindr01': 32, 'parkebl01': 33, 'johnser04': 34, 'arihako01': 35, 'campbpa02': 36, 'boylejo01': 37, 'farrelu01': 38, 'curryxz01': 39, 'bumgama01': 40, 'ortizlu02': 41, 'barrija01': 42, 'meyeral01': 43, 'ortizlu03': 44, 'martefr01': 45, 'murfepe01': 46, 'corbipa01': 47, 'alvarjo02': 48, 'loaisjo01': 49, 'wesneha01': 50, 'kikucyu01': 51, 'smithbu03': 52, 'iveyty01': 53, 'dunnju01': 54, 'eovalna01': 55, 'maydu01': 56, 'teherju01': 57, 'colemdy01': 58, 'knebeco01': 59, 'gipsosa01': 60, 'stratch01': 61, 'peterdi01': 62, 'vinceni01': 63, 'biagijo01': 64, 'rutleja01': 65, 'alberma01': 66, 'livelbe01': 67, 'gearrco01': 68, 'millebo06': 69, 'wittgni01': 70, 'pannoth01': 71, 'vasqura02': 72, 'scholje01': 73, 'worleva01': 74, 'pomerdr01': 75, 'suarean01': 76, 'eliasro01': 77, 'cruzfe01': 78, 'delgara01': 79, 'ceasedy01': 80, 'martibr01': 81, 'irvinja01': 82, 'feltnry01': 83, 'freelky01': 84, 'lucchjo01': 85, 'perdolu02': 86, 'kershcl01': 87, 'couloda01': 88, 'staumjo01': 89, 'castilu02': 90, 'syndeno01': 91, 'crawfku01': 92, 'blancro01': 93, 'hardybl01': 94, 'mizeca01': 95, 'johnspi01': 96, 'eflinza01': 97, 'smeltde01': 98, 'whitemi03': 99, 'cosarja01': 100, 'asheral01': 101, 'eschja01': 102, 'wrighda04': 103, 'diazjh01': 104, 'newcose01': 105, 'payanpe01': 106, 'rossty01': 107, 'rodrije01': 108, 'allarko01': 109, 'wilkad01': 110, 'hoeinbr01': 111, 'valdefr01': 112, 'sadzeco01': 113, 'jacksed01': 114, 'sborzjo01': 115, 'adamsch01': 116, 'hatchto01': 117, 'walstbl01': 118, 'leonedo01': 119, 'borucry01': 120, 'conlopj01': 121, 'francbo01': 122, 'mileywa01': 123, 'hoffmje02': 124, 'stridsp01': 125, 'palumjo01': 126, 'kochma01': 127, 'bettial01': 128, 'searsjp01': 129, 'wrighky01': 130, 'millety01': 131, 'quintjo01': 132, 'suarera01': 133, 'grayjo03': 134, 'matthze01': 135, 'kendrky01': 136, 'glasnty01': 137, 'coleaj01': 138, 'perezwi01': 139, 'ventejo01': 140, 'flaheja01': 141, 'coveydy01': 142, 'wilsobr02': 143, 'hanifbr01': 144, 'effrosc01': 145, 'howarsa01': 146, 'ashcrgr01': 147, 'alberan01': 148, 'gausmke01': 149, 'verhadr01': 150, 'peterda01': 151, 'lambeji01': 152, 'urenajo01': 153, 'halldl01': 154, 'skaggty01': 155, 'goudeas01': 156, 'rossjo01': 157, 'gilmase01': 158, 'sandsco01': 159, 'jarvibr01': 160, 'suterbr01': 161, 'devench02': 162, 'phillty01': 163, 'smithdr01': 164, 'yamamjo01': 165, 'litteza01': 166, 'patinlu01': 167, 'jeffeda01': 168, 'ryanri01': 169, 'shephch01': 170, 'reyesal02': 171, 'neideni01': 172, 'sadleca02': 173, 'avilape01': 174, 'bonilli01': 175, 'bubickr01': 176, 'bellobr01': 177, 'swanser01': 178, 'lauerer01': 179, 'sandopa02': 180, 'bermujo01': 181, 'millebr04': 182, 'cavalca01': 183, 'mazurad01': 184, 'warrewi01': 185, 'boydma01': 186, 'ortka01': 187, 'moyaga01': 188, 'wrighst01': 189, 'gonsoto01': 190, 'briesbe01': 191, 'melviti01': 192, 'detmere01': 193, 'waldike01': 194, 'alzolad01': 195, 'gallayo01': 196, 'cruzst01': 197, 'sparkgl01': 198, 'myersto01': 199, 'duplajo01': 200, 'rodride01': 201, 'richaga01': 202, 'harvema01': 203, 'bibenau01': 204, 'castehu01': 205, 'llovema01': 206, 'manaese01': 207, 'adlemti01': 208, 'ennsdi01': 209, 'claseem01': 210, 'stashco01': 211, 'lorenmi01': 212, 'akinke01': 213, 'manoaal01': 214, 'parkemi01': 215, 'greench03': 216, 'woodal02': 217, 'nelsoji02': 218, 'gracema02': 219, 'simslu01': 220, 'hutchdr01': 221, 'barnech01': 222, 'tarplst01': 223, 'hergeji01': 224, 'robleha01': 225, 'graveke01': 226, 'cainma01': 227, 'suarejo01': 228, 'moorean0 ...
# away_pitcher: {'dunnju01': 328, 'hatchto01': 329, 'iveyty01': 330, 'sadleca02': 331, 'bolsimi01': 332, 'festada01': 333, 'graveke01': 334, 'manoaal01': 335, 'perezwi01': 336, 'eovalna01': 337, 'matthze01': 338, 'cavalca01': 339, 'bettial01': 340, 'meyeral01': 341, 'jeffrje01': 342, 'gallayo01': 343, 'suarean01': 344, 'quintjo01': 345, 'tetreja01': 346, 'perezma02': 347, 'goudeas01': 348, 'campbpa02': 349, 'wainwad01': 350, 'johnspi01': 351, 'rucindr01': 352, 'carraca01': 353, 'scholje01': 354, 'hendrky01': 355, 'gearrco01': 356, 'grayjo03': 357, 'ashcrgr01': 358, 'arihako01': 359, 'vinceni01': 360, 'flynnbr01': 361, 'kimkw01': 362, 'rodrije01': 363, 'jarvibr01': 364, 'sanmare01': 365, 'walstbl01': 366, 'lucchjo01': 367, 'gonzame01': 368, 'sorokmi01': 369, 'sborzjo01': 370, 'hellije01': 371, nan: 372, 'johnsbr02': 373, 'penafe01': 374, 'baumami01': 375, 'raganco01': 376, 'grayjo02': 377, 'battepe01': 378, 'pannoth01': 379, 'gipsosa01': 380, 'lorenmi01': 381, 'peterda01': 382, 'ucetaed01': 383, 'swarmma01': 384, 'alvarjo02': 385, 'smithaj01': 386, 'romose01': 387, 'harvema01': 388, 'cainma01': 389, 'syndeno01': 390, 'francbo01': 391, 'vargace01': 392, 'wrighky01': 393, 'lockewa01': 394, 'erlinro01': 395, 'warrewi01': 396, 'payanpe01': 397, 'eliasro01': 398, 'rodried05': 399, 'blancro01': 400, 'scottch01': 401, 'bermujo01': 402, 'martefr01': 403, 'halldl01': 404, 'fostema01': 405, 'smithbu03': 406, 'festama01': 407, 'bibenau01': 408, 'freelky01': 409, 'stammcr01': 410, 'johnser04': 411, 'wolfja01': 412, 'bumgama01': 413, 'littllu01': 414, 'yamamjo01': 415, 'rossjo01': 416, 'staumjo01': 417, 'stridsp01': 418, 'stashco01': 419, 'buehlwa01': 420, 'barnech01': 421, 'ortizlu03': 422, 'adlemti01': 423, 'klubeco01': 424, 'suarera01': 425, 'rossty01': 426, 'bubickr01': 427, 'waldike01': 428, 'nelsoji02': 429, 'feltnry01': 430, 'sadzeco01': 431, 'smeltde01': 432, 'moorean02': 433, 'sandsco01': 434, 'heanean01': 435, 'llovema01': 436, 'cosarja01': 437, 'mizeca01': 438, 'leiteja01': 439, 'urenajo01': 440, 'delgara01': 441, 'dodddy01': 442, 'jacksed01': 443, 'glasnty01': 444, 'diazjh01': 445, 'boylejo01': 446, 'knebeco01': 447, 'millebo06': 448, 'fulmemi01': 449, 'briesbe01': 450, 'wrighst01': 451, 'rutleja01': 452, 'leonedo01': 453, 'parkebl01': 454, 'manaese01': 455, 'coveydy01': 456, 'pomerdr01': 457, 'simslu01': 458, 'butleed01': 459, 'kikucyu01': 460, 'claseem01': 461, 'lopezpa01': 462, 'sabatc.01': 463, 'feldmsc01': 464, 'stratch01': 465, 'murfepe01': 466, 'wittgni01': 467, 'suarejo01': 468, 'detmere01': 469, 'lambeji01': 470, 'kranima01': 471, 'myersto01': 472, 'boshebu01': 473, 'coleaj01': 474, 'lauerer01': 475, 'allarko01': 476, 'wrighmi01': 477, 'bellch02': 478, 'degroja01': 479, 'litteza01': 480, 'biagijo01': 481, 'teherju01': 482, 'woodal02': 483, 'effrosc01': 484, 'hoffmje02': 485, 'alberma01': 486, 'ortka01': 487, 'asheral01': 488, 'tepesni01': 489, 'avilape01': 490, 'morejad01': 491, 'kochma01': 492, 'lackejo01': 493, 'tarplst01': 494, 'reyesal02': 495, 'suterbr01': 496, 'megilty01': 497, 'barrija01': 498, 'smithdr01': 499, 'palumjo01': 500, 'bonilli01': 501, 'worleva01': 502, 'ryanri01': 503, 'neideni01': 504, 'ceasedy01': 505, 'sparkgl01': 506, 'martibr01': 507, 'corbipa01': 508, 'curryxz01': 509, 'mejiaje02': 510, 'verhadr01': 511, 'cruzfe01': 512, 'howarsa01': 513, 'slegeaa01': 514, 'kendrky01': 515, 'farrelu01': 516, 'crawfku01': 517, 'hardybl01': 518, 'patinlu01': 519, 'swanser01': 520, 'soriage01': 521, 'gonsoto01': 522, 'colemdy01': 523, 'loaisjo01': 524, 'szaputh01': 525, 'bellobr01': 526, 'livelbe01': 527, 'couloda01': 528, 'ceccosl01': 529, 'vasqura02': 530, 'juradar01': 531, 'ortizlu02': 532, 'weavelu01': 533, 'moyaga01': 534, 'davieza02': 535, 'gilmase01': 536, 'sandopa02': 537, 'anderdr02': 538, 'millety01': 539, 'jennida01': 540, 'perdolu02': 541, 'flaheja01': 542, 'searsjp01': 543, 'wilkad01': 544, 'heasljo01': 545, 'hancoem01': 546, 'hergeji01': 547, 'akinke01': 548, 'gracema02': 549, 'wrighda04': 550, 'bedroc ...

# %%
# Map unique names to integers for both features without overlap
def map_non_overlapping_features(df, columns):
    # Collect unique names for each column
    mappings = {}
    current_index = 0
    for column in columns:
        unique_names = df[column].unique()
        column_mapping = {name: current_index + idx for idx, name in enumerate(unique_names)}
        mappings[column] = column_mapping
        current_index += len(unique_names)  # Ensure no overlap in indices
        # Apply the mapping
        df[column] = df[column].map(column_mapping)
    return df, mappings

# Apply to 'home_pitcher' and 'away_pitcher'
columns_to_map = ['home_team_abbr', 'away_team_abbr']
train_data, mappings = map_non_overlapping_features(train_data, columns_to_map)

# Display the result
print(train_data)
print("Mapping dictionaries:")
for column, mapping in mappings.items():
    print(f"{column}: {mapping}")
# Out:
#         id  home_team_abbr  away_team_abbr  is_night_game  home_pitcher  \
# 0        0               0              30            0.0             0
# 1        1               1              31            1.0             1
# 2        2               2              32            1.0             2
# 3        3               3              33            1.0             3
# 4        4               4              30            0.0             4
# ...    ...             ...             ...            ...           ...
# 2423  2423              18              36            0.0           327
# 2424  2424               6              51            1.0            18
# 2425  2425              13              59            1.0            47
# 2426  2426               7              58            1.0           104
# 2427  2427              14              58            0.0            17
#
#       away_pitcher  home_team_rest  away_team_rest  home_pitcher_rest  \
# 0              328             1.0             1.0                7.0
# 1              329             1.0             2.0               13.0
# 2              330             1.0             1.0                6.0
# 3              331             1.0             1.0                6.0
# 4              332             NaN             NaN                6.0
# ...            ...             ...             ...                ...
# 2423           504             1.0             1.0                7.0
# 2424           591             1.0             1.0                6.0
# 2425           563             1.0             1.0                7.0
# 2426           506             1.0             1.0                6.0
# 2427           506             1.0             1.0                5.0
#
#       away_pitcher_rest  ...  away_pitcher_H_batters_faced_skew  \
# 0                   6.0  ...                           1.137587
# 1                   6.0  ...                           0.977567
# 2                   NaN  ...                           0.787161
# 3                   6.0  ...                           1.845729
# 4                   NaN  ...                                NaN
# ...                 ...  ...                                ...
# 2423                5.0  ...                          -0.355111
# 2424                5.0  ...                          -0.328963
# 2425               46.0  ...                          -0.910894
# 2426                6.0  ...                          -0.508469
# 2427                6.0  ...                          -0.546845
#
#       away_pitcher_BB_batters_faced_mean  away_pitcher_BB_batters_faced_std  \
# 0                              -0.202847                          -0.169020
# 1                              -0.714865                          -0.838365
# 2                              -0.220152                          -0.530733
# 3                               1.178937                           1.585955
# 4                               1.609123                                NaN
# ...                                  ...                                ...
# 2423                           -2.021044                          -1.344937
# 2424                           -0.131224                           0.386066
# 2425                           -0.771246                          -0.523058
# 2426                            0.009715                           1.124424
# 2427                            0.069352                           1.576071
#
#       away_pitcher_BB_batters_faced_skew  \
# 0                              -0.365553
# 1                              -0.428443
# 2                              -1.110442
# 3                               0.066516
# 4                                    NaN
# ...                                  ...
# 2423                            1.476650
# 2424                           -0.677908
# 2425                            0.146930
# 2426                            0.742245
# 2427                            0.564578
#
#       away_pitcher_leverage_index_avg_mean  \
# 0                                -0.227047
# 1                                -0.124948
# 2                                -0.549621
# 3                                 0.521931
# 4                                 1.025560
# ...                                    ...
# 2423                             -0.512116
# 2424                             -0.919306
# 2425                              0.157603
# 2426                              0.806562
# 2427                              1.156825
#
#       away_pitcher_leverage_index_avg_std  \
# 0                               -0.295909
# 1                               -0.281637
# 2                               -0.021826
# 3                               -0.393085
# 4                                     NaN
# ...                                   ...
# 2423                            -0.686262
# 2424                            -0.354241
# 2425                            -0.764696
# 2426                             2.978556
# 2427                             3.574703
#
#       away_pitcher_leverage_index_avg_skew  away_pitcher_wpa_def_mean  \
# 0                                 0.686374                  -0.203924
# 1                                 1.065657                  -0.282993
# 2                                 0.494930                  -1.128590
# 3                                 0.712029                   0.546615
# 4                                      NaN                  -0.600823
# ...                                    ...                        ...
# 2423                                   NaN                   0.191498
# 2424                              0.252490                  -1.200417
# 2425                             -0.709722                  -0.438879
# 2426                              1.911847                   0.486277
# 2427                              1.627607                   0.565352
#
#       away_pitcher_wpa_def_std  away_pitcher_wpa_def_skew
# 0                     0.245775                  -0.510284
# 1                          NaN                   0.191600
# 2                    -0.184698                   0.851088
# 3                    -0.240162                  -0.625477
# 4                          NaN                        NaN
# ...                        ...                        ...
# 2423                       NaN                   0.187264
# 2424                  1.247802                   0.616256
# 2425                 -0.397830                   1.075658
# 2426                 -0.044440                   1.138141
# 2427                       NaN                   1.495294
#
# [2428 rows x 165 columns]
# Mapping dictionaries:
# home_team_abbr: {'DPS': 0, 'JEM': 1, 'MZG': 2, 'GKO': 3, 'UPV': 4, 'VQC': 5, 'SAJ': 6, 'FBW': 7, 'QDH': 8, 'KFH': 9, 'YHA': 10, 'STC': 11, 'RLJ': 12, 'RKN': 13, 'PJT': 14, 'GUT': 15, 'ZQF': 16, 'MOO': 17, 'PDF': 18, 'QPO': 19, 'JBM': 20, 'HXK': 21, 'BPH': 22, 'VJV': 23, 'KJP': 24, 'XFB': 25, 'GLO': 26, 'ECN': 27, 'HAN': 28, 'RAV': 29}
# away_team_abbr: {'SAJ': 30, 'GKO': 31, 'HAN': 32, 'JEM': 33, 'GUT': 34, 'HXK': 35, 'KFH': 36, 'UPV': 37, 'XFB': 38, 'RLJ': 39, 'JBM': 40, 'STC': 41, 'PDF': 42, 'GLO': 43, 'QPO': 44, 'BPH': 45, 'YHA': 46, 'MZG': 47, 'QDH': 48, 'FBW': 49, 'ZQF': 50, 'VJV': 51, 'RAV': 52, 'PJT': 53, 'ECN': 54, 'MOO': 55, 'RKN': 56, 'KJP': 57, 'VQC': 58, 'DPS': 59}

# %%
# Drop non-integer and non-float columns
train_data = train_data.select_dtypes(include=['int64', 'float64'])

# Display the resulting DataFrame
print(train_data)
# Out:
#         id  home_team_abbr  away_team_abbr  is_night_game  home_pitcher  \
# 0        0               0              30            0.0             0
# 1        1               1              31            1.0             1
# 2        2               2              32            1.0             2
# 3        3               3              33            1.0             3
# 4        4               4              30            0.0             4
# ...    ...             ...             ...            ...           ...
# 2423  2423              18              36            0.0           327
# 2424  2424               6              51            1.0            18
# 2425  2425              13              59            1.0            47
# 2426  2426               7              58            1.0           104
# 2427  2427              14              58            0.0            17
#
#       away_pitcher  home_team_rest  away_team_rest  home_pitcher_rest  \
# 0              328             1.0             1.0                7.0
# 1              329             1.0             2.0               13.0
# 2              330             1.0             1.0                6.0
# 3              331             1.0             1.0                6.0
# 4              332             NaN             NaN                6.0
# ...            ...             ...             ...                ...
# 2423           504             1.0             1.0                7.0
# 2424           591             1.0             1.0                6.0
# 2425           563             1.0             1.0                7.0
# 2426           506             1.0             1.0                6.0
# 2427           506             1.0             1.0                5.0
#
#       away_pitcher_rest  ...  away_pitcher_H_batters_faced_skew  \
# 0                   6.0  ...                           1.137587
# 1                   6.0  ...                           0.977567
# 2                   NaN  ...                           0.787161
# 3                   6.0  ...                           1.845729
# 4                   NaN  ...                                NaN
# ...                 ...  ...                                ...
# 2423                5.0  ...                          -0.355111
# 2424                5.0  ...                          -0.328963
# 2425               46.0  ...                          -0.910894
# 2426                6.0  ...                          -0.508469
# 2427                6.0  ...                          -0.546845
#
#       away_pitcher_BB_batters_faced_mean  away_pitcher_BB_batters_faced_std  \
# 0                              -0.202847                          -0.169020
# 1                              -0.714865                          -0.838365
# 2                              -0.220152                          -0.530733
# 3                               1.178937                           1.585955
# 4                               1.609123                                NaN
# ...                                  ...                                ...
# 2423                           -2.021044                          -1.344937
# 2424                           -0.131224                           0.386066
# 2425                           -0.771246                          -0.523058
# 2426                            0.009715                           1.124424
# 2427                            0.069352                           1.576071
#
#       away_pitcher_BB_batters_faced_skew  \
# 0                              -0.365553
# 1                              -0.428443
# 2                              -1.110442
# 3                               0.066516
# 4                                    NaN
# ...                                  ...
# 2423                            1.476650
# 2424                           -0.677908
# 2425                            0.146930
# 2426                            0.742245
# 2427                            0.564578
#
#       away_pitcher_leverage_index_avg_mean  \
# 0                                -0.227047
# 1                                -0.124948
# 2                                -0.549621
# 3                                 0.521931
# 4                                 1.025560
# ...                                    ...
# 2423                             -0.512116
# 2424                             -0.919306
# 2425                              0.157603
# 2426                              0.806562
# 2427                              1.156825
#
#       away_pitcher_leverage_index_avg_std  \
# 0                               -0.295909
# 1                               -0.281637
# 2                               -0.021826
# 3                               -0.393085
# 4                                     NaN
# ...                                   ...
# 2423                            -0.686262
# 2424                            -0.354241
# 2425                            -0.764696
# 2426                             2.978556
# 2427                             3.574703
#
#       away_pitcher_leverage_index_avg_skew  away_pitcher_wpa_def_mean  \
# 0                                 0.686374                  -0.203924
# 1                                 1.065657                  -0.282993
# 2                                 0.494930                  -1.128590
# 3                                 0.712029                   0.546615
# 4                                      NaN                  -0.600823
# ...                                    ...                        ...
# 2423                                   NaN                   0.191498
# 2424                              0.252490                  -1.200417
# 2425                             -0.709722                  -0.438879
# 2426                              1.911847                   0.486277
# 2427                              1.627607                   0.565352
#
#       away_pitcher_wpa_def_std  away_pitcher_wpa_def_skew
# 0                     0.245775                  -0.510284
# 1                          NaN                   0.191600
# 2                    -0.184698                   0.851088
# 3                    -0.240162                  -0.625477
# 4                          NaN                        NaN
# ...                        ...                        ...
# 2423                       NaN                   0.187264
# 2424                  1.247802                   0.616256
# 2425                 -0.397830                   1.075658
# 2426                 -0.044440                   1.138141
# 2427                       NaN                   1.495294
#
# [2428 rows x 163 columns]

# %%
from sklearn.linear_model import LinearRegression
print("LinearRegression imported successfully!")
# Out:
# LinearRegression imported successfully!

# %%
# Check if there are any NaN values in the DataFrame
has_nan = train_data.isna().any().any()

# Output the result
if has_nan:
    print("There are NaN values in train_data.")
else:
    print("No NaN values in train_data.")
# Out:
# There are NaN values in train_data.

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from tqdm import tqdm

def fill_missing_using_correlation(df):
    # Compute the correlation matrix
    corr_matrix = df.corr()

    # Iterate over each column
    for col in tqdm(df.columns):
        if df[col].isna().any():  # Only process columns with missing values
            # Find the column with the highest absolute correlation to the current column
            if corr_matrix[col].drop(col).isna().all():
                # Skip if all correlations are NaN
                continue
            corr_col = corr_matrix[col].drop(col).idxmax()

            # Check if the correlated column is valid
            if pd.isna(corr_col):
                # Skip if no valid correlation column exists
                continue

            # Drop rows where either column is NaN to fit the linear model
            valid_data = df[[col, corr_col]].dropna()
            if valid_data.empty or valid_data[corr_col].isna().all():
                # Skip if no valid data exists for linear regression
                continue

            # Fit a linear regression model
            X = valid_data[[corr_col]].values.reshape(-1, 1)  # Independent variable
            y = valid_data[col].values                        # Dependent variable
            model = LinearRegression()
            model.fit(X, y)

            # Handle missing values in the correlated column
            missing_corr_col_indices = df[df[corr_col].isna()].index
            if not missing_corr_col_indices.empty:
                # Fill missing correlated column values with its mean
                df.loc[missing_corr_col_indices, corr_col] = df[corr_col].mean()

            # Predict missing values using the linear model
            missing_indices = df[df[col].isna()].index
            df.loc[missing_indices, col] = model.predict(df.loc[missing_indices, [corr_col]].values.reshape(-1, 1))

            # Fill any remaining NaN with the column mean as fallback
            df[col] = df[col].fillna(df[col].mean())

    # Handle rows that are entirely NaN by filling with column means
    df = df.apply(lambda row: row.fillna(df.mean()), axis=1)

    return df

# Example usage
# Assume train_data is your DataFrame with missing values
train_data = fill_missing_using_correlation(train_data)

# Display the result
print(train_data)
# Out:
# 100%|██████████| 163/163 [00:00<00:00, 548.25it/s]
#           id  home_team_abbr  away_team_abbr  is_night_game  home_pitcher  \
# 0        0.0             0.0            30.0            0.0           0.0
# 1        1.0             1.0            31.0            1.0           1.0
# 2        2.0             2.0            32.0            1.0           2.0
# 3        3.0             3.0            33.0            1.0           3.0
# 4        4.0             4.0            30.0            0.0           4.0
# ...      ...             ...             ...            ...           ...
# 2423  2423.0            18.0            36.0            0.0         327.0
# 2424  2424.0             6.0            51.0            1.0          18.0
# 2425  2425.0            13.0            59.0            1.0          47.0
# 2426  2426.0             7.0            58.0            1.0         104.0
# 2427  2427.0            14.0            58.0            0.0          17.0
#
#       away_pitcher  home_team_rest  away_team_rest  home_pitcher_rest  \
# 0            328.0        1.000000        1.000000                7.0
# 1            329.0        1.000000        2.000000               13.0
# 2            330.0        1.000000        1.000000                6.0
# 3            331.0        1.000000        1.000000                6.0
# 4            332.0        1.160925        1.139328                6.0
# ...            ...             ...             ...                ...
# 2423         504.0        1.000000        1.000000                7.0
# 2424         591.0        1.000000        1.000000                6.0
# 2425         563.0        1.000000        1.000000                7.0
# 2426         506.0        1.000000        1.000000                6.0
# 2427         506.0        1.000000        1.000000                5.0
#
#       away_pitcher_rest  ...  away_pitcher_H_batters_faced_skew  \
# 0              6.000000  ...                           1.137587
# 1              6.000000  ...                           0.977567
# 2              7.946207  ...                           0.787161
# 3              6.000000  ...                           1.845729
# 4              7.778897  ...                           0.144047
# ...                 ...  ...                                ...
# 2423           5.000000  ...                          -0.355111
# 2424           5.000000  ...                          -0.328963
# 2425          46.000000  ...                          -0.910894
# 2426           6.000000  ...                          -0.508469
# 2427           6.000000  ...                          -0.546845
#
#       away_pitcher_BB_batters_faced_mean  away_pitcher_BB_batters_faced_std  \
# 0                              -0.202847                          -0.169020
# 1                              -0.714865                          -0.838365
# 2                              -0.220152                          -0.530733
# 3                               1.178937                           1.585955
# 4                               1.609123                           0.957246
# ...                                  ...                                ...
# 2423                           -2.021044                          -1.344937
# 2424                           -0.131224                           0.386066
# 2425                           -0.771246                          -0.523058
# 2426                            0.009715                           1.124424
# 2427                            0.069352                           1.576071
#
#       away_pitcher_BB_batters_faced_skew  \
# 0                              -0.365553
# 1                              -0.428443
# 2                              -1.110442
# 3                               0.066516
# 4                               0.397677
# ...                                  ...
# 2423                            1.476650
# 2424                           -0.677908
# 2425                            0.146930
# 2426                            0.742245
# 2427                            0.564578
#
#       away_pitcher_leverage_index_avg_mean  \
# 0                                -0.227047
# 1                                -0.124948
# 2                                -0.549621
# 3                                 0.521931
# 4                                 1.025560
# ...                                    ...
# 2423                             -0.512116
# 2424                             -0.919306
# 2425                              0.157603
# 2426                              0.806562
# 2427                              1.156825
#
#       away_pitcher_leverage_index_avg_std  \
# 0                               -0.295909
# 1                               -0.281637
# 2                               -0.021826
# 3                               -0.393085
# 4                               -0.096506
# ...                                   ...
# 2423                            -0.686262
# 2424                            -0.354241
# 2425                            -0.764696
# 2426                             2.978556
# 2427                             3.574703
#
#       away_pitcher_leverage_index_avg_skew  away_pitcher_wpa_def_mean  \
# 0                                 0.686374                  -0.203924
# 1                                 1.065657                  -0.282993
# 2                                 0.494930                  -1.128590
# 3                                 0.712029                   0.546615
# 4                                 0.087313                  -0.600823
# ...                                    ...                        ...
# 2423                             -0.179652                   0.191498
# 2424                              0.252490                  -1.200417
# 2425                             -0.709722                  -0.438879
# 2426                              1.911847                   0.486277
# 2427                              1.627607                   0.565352
#
#       away_pitcher_wpa_def_std  away_pitcher_wpa_def_skew
# 0                     0.245775                  -0.510284
# 1                     0.132556                   0.191600
# 2                    -0.184698                   0.851088
# 3                    -0.240162                  -0.625477
# 4                     0.098076                   0.220135
# ...                        ...                        ...
# 2423                 -0.066381                   0.187264
# 2424                  1.247802                   0.616256
# 2425                 -0.397830                   1.075658
# 2426                 -0.044440                   1.138141
# 2427                 -0.120541                   1.495294
#
# [2428 rows x 163 columns]

# %%
# Check if there are any NaN values in the DataFrame
has_nan = train_data.isna().any().any()

# Output the result
if has_nan:
    print("There are NaN values in train_data.")
else:
    print("No NaN values in train_data.")
# Out:
# No NaN values in train_data.

# %%
# Save the DataFrame to a CSV file
train_data.to_csv('./stage2_data/stage2_test_data_imputation.csv', index=False)

print("train_data has been saved to train_data_imputation.csv")
# Out:
# train_data has been saved to train_data_imputation.csv
